# %%
import pandas as pd
gd=pd.read_csv("/content/grad.csv")
gd
# Out:
#     Unnamed: 0   Names Initials  SEM1  SEM2  SEM3 Grade  Placed  mean
# 0            0     Joe        K   9.8  10.0   9.9    A+       1  29.7
# 1            1  Rajesh        M   8.9   9.1   9.3     A       1  27.3
# 2            2  Kissan        V   9.9   9.8  10.0     A       0  29.7
# 3            3    Mary        N   7.7   8.0   NaN     B       0   NaN
# 4            4    Jeen        K   9.8   9.1   9.9    A+       1  28.8
# 5            5     Raj        M   8.9   9.1   9.3     A       1  27.3
# 6            6  Hassan        V   9.9   9.0   9.2     A       1  28.1
# 7            7    Mari        N   7.7   8.0   7.1     B       1  22.8
# 8            8    Jess        K   NaN   9.1   9.9    A+       1   NaN
# 9            9  Rajini        M   NaN   9.1   9.3     A       0   NaN
# 10          10   Kiran        V   NaN   9.3   9.2     A       0   NaN
# 11          11    Maya        N   7.7   8.0   7.1     B       0  22.8
# ...

# %%
import seaborn as sns
p1=sns.lineplot(x="SEM1",y="SEM2",data=gd)

# %%
p1=sns.relplot(data=gd,x="SEM1",y="SEM2",col="Placed")

# %%
di=pd.read_excel("/content/diabetes.xlsx")
di.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
#create a relational plot using age as y axis index as x axis seperated by class
di["Index"] =range(1,769)
p2=sns.relplot(data=di,y="age",x="Index",col="class")

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="sex",)

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="size",style="time",palette="bright")

# %%
dj=sns.load_dataset("dowjones")
dj.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
import seaborn as sns
sns.relplot(data=dj,x="Date",y="Price",kind="line")

# %%
fm=sns.load_dataset("fmri")
fm
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.catplot(data=tips,x="time",y="total-bill",kind="violin",hue="smoker")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-8c27c309d27f> in <cell line: 1>()
# ----> 1 sns.catplot(data=tips,x="time",y="total-bill",kind="violin",hue="smoker")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779             raise ValueError("Cannot pass values for both `x` and `y`.")
#    2780
# -> 2781     p = Plotter(
#    2782         data=data,
#    2783         variables=dict(
#
# ...

# %%
sns.catplot(data=fm,x="subject",y="timepoint",)

# %%
sns.relplot(data=fm,x="subject",y="timepoint",hue="event")

# %%
sns.catplot(data=fm,x="subject",y="timepoint",hue="event")

# %%
sns.catplot(data=tips,x="time",y="total_bill",kind="violin",hue="smoker")
