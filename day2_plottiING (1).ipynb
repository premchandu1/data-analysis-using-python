# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5,6,]
y=[9,9,9,9,9,9]
plt.plot(x,y)#line graph
plt.title("my first plot")
plt.xlabel("x values")
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
sub=["psy","nanco","med","onc","ant"]
s1=[67,45,73,71,57]
s2=[43,67,68,53,85]
cut=[70,70,70,70,70]
plt.plot(sub,s1,label="student1",color="k")
plt.plot(sub,s2,label="student2",color="b")
plt.plot(cut,label="cutoff",color="y")
plt.legend()
plt.title("good student")
plt.xlabel("subject")
plt.ylabel(["marks"])
# Out:
# Text(0, 0.5, "['marks']")

# %%
from matplotlib import pyplot as plt

i=np.array([25,51,84,131,160,189,220,250,267,297])
a=np.array([15,41,94,110,151])
over1=np.arange(5,51,5)
over2=np.arange(5,26,5)
plt.plot(over1,i,label="india",color="blue",marker=">")
plt.plot(over2,a,label="australia",color="yellow",marker="p")
plt.title("indai vs australia")
plt.xlabel("overs")
plt.ylabel("runs")
plt.legend()
